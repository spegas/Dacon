# %% [markdown]
# <a href="https://colab.research.google.com/github/spegas/Dacon/blob/main/Get_Stock_List_ipynb_20240518.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# 초기 import 설정
import os, sys
from google.colab import drive

# %%
# Google drive 마운트
drive.mount('/content/drive/')
# Out:
# Mounted at /content/drive/

# %%
# !pip install finance-datareader
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 46.6/46.6 kB 1.7 MB/s eta 0:00:00
# ...

# %%
# !pip install wget
# Out:
# ...
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for wget: filename=wget-3.2-py3-none-any.whl size=9656 sha256=86cc814dcf78bd0f534ba7df45dfbf385b9fa2cad994efb01d2faee70573ca6e
#   Stored in directory: /root/.cache/pip/wheels/8b/f1/7f/5c94f0a7a505ca1c81cd1d9208ae2064675d97582078e6c769
# Successfully built wget
# ...

# %%
import pandas as pd
import numpy as np

# %%
# FinanceDataReader 를 fdr 별칭으로 불러옵니다.
# 라이브러리의 version을 확인하고 싶을 때는 .__version__ 으로 확인합니다.
import FinanceDataReader as fdr
fdr.__version__
# Out:
# '0.9.90'

# %%
# KRX : KRX 종목 전체
# KOSPI : KOSPI 종목
# KOSDAQ : KOSDAQ 종목
# KONEX : KONEX 종목
# NASDAQ : 나스닥 종목
# NYSE : 뉴욕증권거래소 종목
# SP500 : S&P500 종목

# 한국거래소 상장종목 전체 가져오기
pd_df_krx = fdr.StockListing("KRX")

# %%
# 가져온 KRX 상장종목 리스트중 일부 출력
pd_df_krx.head()
# Out:
#      Code        ISU_CD      Name Market Dept   Close ChangeCode  Changes  \
# 0  005930  KR7005930003      삼성전자  KOSPI        77400          2     -800
# 1  000660  KR7000660001    SK하이닉스  KOSPI       189900          2    -3100
# 2  373220  KR7373220003  LG에너지솔루션  KOSPI       376500          2    -5000
# 3  207940  KR7207940008  삼성바이오로직스  KOSPI       788000          1     4000
# 4  005935  KR7005931001     삼성전자우  KOSPI        64300          2     -400
#
#    ChagesRatio    Open    High     Low    Volume         Amount  \
# 0        -1.02   78600   78800   77200  15918201  1237640369900
# 1        -1.61  192000  193500  189900   2841394   544088599400
# 2        -1.31  381500  384000  376000    175717    66453267500
# 3         0.51  783000  791000  782000     45694    36001689000
# 4        -0.62   64800   64800   64000    945505    60771049266
#
#             Marcap      Stocks MarketId
# 0  462061169370000  5969782550      STK
# 1  138247649113500   728002365      STK
# ...

# %%
# KRX 상장종목 리스트 행과 열의 크기를 봅니다.(행, 열) 순
pd_df_krx.shape
# Out:
# (2808, 17)

# %%
# 전체 KRX 데이터프레임의 요약정보를 봅니다.
pd_df_krx.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2808 entries, 0 to 2807
# Data columns (total 17 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Code         2808 non-null   object
#  1   ISU_CD       2808 non-null   object
#  2   Name         2808 non-null   object
#  3   Market       2808 non-null   object
#  4   Dept         2808 non-null   object
#  5   Close        2808 non-null   object
#  6   ChangeCode   2808 non-null   object
#  7   Changes      2808 non-null   int64
#  8   ChagesRatio  2808 non-null   float64
#  9   Open         2808 non-null   int64
#  10  High         2808 non-null   int64
#  11  Low          2808 non-null   int64
#  12  Volume       2808 non-null   int64
#  13  Amount       2808 non-null   int64
#  14  Marcap       2808 non-null   int64
#  15  Stocks       2808 non-null   int64
#  16  MarketId     2808 non-null   object
# dtypes: float64(1), int64(8), object(8)
# memory usage: 373.1+ KB

# %%
# 전체 KRX 데이터프레임의 기술통계 값을 요약합니다.
pd_df_krx.describe()
# Out:
#              Changes  ChagesRatio           Open           High  \
# count    2808.000000  2808.000000    2808.000000    2808.000000
# mean      -58.169516    -0.593629   20331.848291   20746.422365
# std      2707.722492     3.687007   50100.815500   51345.362621
# min    -28700.000000   -30.000000       0.000000       0.000000
# 25%      -140.000000    -1.690000    2373.750000    2420.000000
# 50%       -15.000000    -0.400000    6050.000000    6150.000000
# 75%        10.000000     0.290000   15950.000000   16017.500000
# max    103000.000000    43.500000  783000.000000  791000.000000
#
#                  Low        Volume        Amount        Marcap        Stocks
# count    2808.000000  2.808000e+03  2.808000e+03  2.808000e+03  2.808000e+03
# mean    19947.340456  5.397260e+05  7.214302e+09  9.403881e+11  4.202612e+07
# std     49452.142723  3.065995e+06  4.279665e+10  9.723969e+12  1.334077e+08
# min         0.000000  0.000000e+00  0.000000e+00  7.960000e+08  2.000000e+05
# ...

# %%
# KRX 종목 리스트를 저장하기 위한 디렉토리 설정
save_base_dir = '/content/drive/MyDrive/Stock/list/'
save_krx_save_filename = save_base_dir +  str('krx_stock_list.csv')
print(save_krx_save_filename)
# Out:
# /content/drive/MyDrive/Stock/list/krx_stock_list.csv

# %%
# 설정한 저장 파일이름 KRX 종목 리스트 정보를 CSV로 저장.
pd_df_krx.to_csv(save_krx_save_filename, index=False)

# %%
# 설정한 저장 파일이름에 KRX 종목 리스트 값이 잘 저장 되었는지 해당 파일에서 데이터를 로드 함.
load_df_krx = pd.read_csv(save_krx_save_filename, header=0)

# %%
# 로드한 정보의 일부를 출력 함.
load_df_krx.head()
# Out:
#      Code        ISU_CD      Name Market Dept   Close  ChangeCode  Changes  \
# 0  005930  KR7005930003      삼성전자  KOSPI  NaN   77400           2     -800
# 1  000660  KR7000660001    SK하이닉스  KOSPI  NaN  189900           2    -3100
# 2  373220  KR7373220003  LG에너지솔루션  KOSPI  NaN  376500           2    -5000
# 3  207940  KR7207940008  삼성바이오로직스  KOSPI  NaN  788000           1     4000
# 4  005935  KR7005931001     삼성전자우  KOSPI  NaN   64300           2     -400
#
#    ChagesRatio    Open    High     Low    Volume         Amount  \
# 0        -1.02   78600   78800   77200  15918201  1237640369900
# 1        -1.61  192000  193500  189900   2841394   544088599400
# 2        -1.31  381500  384000  376000    175717    66453267500
# 3         0.51  783000  791000  782000     45694    36001689000
# 4        -0.62   64800   64800   64000    945505    60771049266
#
#             Marcap      Stocks MarketId
# 0  462061169370000  5969782550      STK
# 1  138247649113500   728002365      STK
# ...
